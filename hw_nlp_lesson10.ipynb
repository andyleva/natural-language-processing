# %% [markdown]
# ### КУРС "Введение в обработку естественного языка"

# %% [markdown]
# #### дз к уроку 10 “Перевод без механизма внимания SEQ2SEQ модель”

# %% [markdown]
# Разобраться с моделькой перевода (без механизма внимания) как она устроена, запустить для перевода с русского на английский (при желании можно взять другие пары языков)

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import sklearn
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
devices = tf.config.list_physical_devices('GPU')
devices
# Out:
# []

# %% [markdown]
# !wget http://www.manythings.org/anki/rus-eng.zip
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/

# %%
# !ls ./rus-eng/
# Out:
# "ls" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
path_to_file = './rus-eng/rus.txt'

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence('Just do it!')
# Out:
# '<start> just do it ! <end>'

# %%
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[140])
print(ru[140])
# Out:
# <start> i lied . <end>
# <start> я солгал . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Let's create model and train it

# %%
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, 
                                                                                                target_tensor,
                                                                                                test_size=0.2)

# %%
def convert(lang, tensor):
    for t in tensor:
        if t != 0:
            print(f"{t} ----> {lang.index_word[t]}")

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 4 ----> я
# 75 ----> никогда
# 7 ----> не
# 820 ----> пью
# 181 ----> одна
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 4 ----> i
# 104 ----> never
# 211 ----> drink
# 119 ----> alone
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# #### create a tf.data and dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train) // BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences = False,
                                       return_state= True,
                                       recurrent_initializer = 'glorot_uniform')
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return state
    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences = True,
                                       return_state = True,
                                       recurrent_initializer = 'glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)
    
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        x = self.fc(output)
        
        return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %% [markdown]
# #### optimizer and loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_text_translate_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %% [markdown]
# #### let's training

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6398
# Epoch 1 Batch 100 Loss 2.1077
# Epoch 1 Batch 200 Loss 1.7835
# Epoch 1 Batch 300 Loss 1.6146
# Epoch 1 Batch 400 Loss 1.5024
# Epoch 1 Batch 500 Loss 1.4629
# Epoch 1 Batch 600 Loss 1.3938
# Epoch 1 Batch 700 Loss 1.2825
# Epoch 1 Batch 800 Loss 1.2586
# Epoch 1 Batch 900 Loss 1.1891
# Epoch 1 Batch 1000 Loss 1.2587
# Epoch 1 Batch 1100 Loss 1.0392
# Epoch 1 Batch 1200 Loss 0.9754
# Epoch 1 Loss 1.4506
# Time taken for 1 epoch 1264.1662464141846 sec
#
# Epoch 2 Batch 0 Loss 0.9118
# Epoch 2 Batch 100 Loss 0.9356
# Epoch 2 Batch 200 Loss 0.8833
# Epoch 2 Batch 300 Loss 0.9317
# Epoch 2 Batch 400 Loss 0.7873
# Epoch 2 Batch 500 Loss 0.8788
# Epoch 2 Batch 600 Loss 0.7924
# Epoch 2 Batch 700 Loss 0.7030
# Epoch 2 Batch 800 Loss 0.6695
# Epoch 2 Batch 900 Loss 0.6539
# Epoch 2 Batch 1000 Loss 0.5643
# Epoch 2 Batch 1100 Loss 0.6885
# Epoch 2 Batch 1200 Loss 0.6019
# Epoch 2 Loss 0.7770
# Time taken for 1 epoch 1518.204639673233 sec
#
# Epoch 3 Batch 0 Loss 0.5024
# Epoch 3 Batch 100 Loss 0.4817
# Epoch 3 Batch 200 Loss 0.5611
# Epoch 3 Batch 300 Loss 0.4831
# Epoch 3 Batch 400 Loss 0.4728
# Epoch 3 Batch 500 Loss 0.4907
# Epoch 3 Batch 600 Loss 0.4558
# Epoch 3 Batch 700 Loss 0.4801
# Epoch 3 Batch 800 Loss 0.5148
# Epoch 3 Batch 900 Loss 0.4569
# Epoch 3 Batch 1000 Loss 0.3899
# Epoch 3 Batch 1100 Loss 0.4345
# Epoch 3 Batch 1200 Loss 0.4182
# Epoch 3 Loss 0.4513
# Time taken for 1 epoch 1320.392330646515 sec
#
# Epoch 4 Batch 0 Loss 0.3019
# Epoch 4 Batch 100 Loss 0.2646
# Epoch 4 Batch 200 Loss 0.2746
# Epoch 4 Batch 300 Loss 0.2741
# Epoch 4 Batch 400 Loss 0.2695
# Epoch 4 Batch 500 Loss 0.2930
# Epoch 4 Batch 600 Loss 0.3007
# Epoch 4 Batch 700 Loss 0.3006
# Epoch 4 Batch 800 Loss 0.2266
# Epoch 4 Batch 900 Loss 0.2567
# Epoch 4 Batch 1000 Loss 0.2991
# Epoch 4 Batch 1100 Loss 0.2518
# Epoch 4 Batch 1200 Loss 0.3285
# Epoch 4 Loss 0.2733
# Time taken for 1 epoch 1236.8834772109985 sec
#
# Epoch 5 Batch 0 Loss 0.1846
# Epoch 5 Batch 100 Loss 0.1392
# Epoch 5 Batch 200 Loss 0.1589
# Epoch 5 Batch 300 Loss 0.1747
# Epoch 5 Batch 400 Loss 0.2149
# Epoch 5 Batch 500 Loss 0.1750
# Epoch 5 Batch 600 Loss 0.1396
# Epoch 5 Batch 700 Loss 0.2059
# Epoch 5 Batch 800 Loss 0.2078
# Epoch 5 Batch 900 Loss 0.1538
# Epoch 5 Batch 1000 Loss 0.2086
# Epoch 5 Batch 1100 Loss 0.1928
# Epoch 5 Batch 1200 Loss 0.1972
# Epoch 5 Loss 0.1804
# Time taken for 1 epoch 1170.5686104297638 sec
#
# Epoch 6 Batch 0 Loss 0.1107
# Epoch 6 Batch 100 Loss 0.1123
# Epoch 6 Batch 200 Loss 0.1268
# Epoch 6 Batch 300 Loss 0.1548
# Epoch 6 Batch 400 Loss 0.1181
# Epoch 6 Batch 500 Loss 0.1367
# Epoch 6 Batch 600 Loss 0.1158
# Epoch 6 Batch 700 Loss 0.1210
# Epoch 6 Batch 800 Loss 0.1464
# Epoch 6 Batch 900 Loss 0.1476
# Epoch 6 Batch 1000 Loss 0.1279
# Epoch 6 Batch 1100 Loss 0.1196
# Epoch 6 Batch 1200 Loss 0.1154
# Epoch 6 Loss 0.1335
# Time taken for 1 epoch 1167.668592453003 sec
#
# Epoch 7 Batch 0 Loss 0.1238
# Epoch 7 Batch 100 Loss 0.0923
# Epoch 7 Batch 200 Loss 0.0964
# Epoch 7 Batch 300 Loss 0.0797
# Epoch 7 Batch 400 Loss 0.0949
# Epoch 7 Batch 500 Loss 0.0803
# Epoch 7 Batch 600 Loss 0.0936
# Epoch 7 Batch 700 Loss 0.1564
# Epoch 7 Batch 800 Loss 0.1036
# Epoch 7 Batch 900 Loss 0.0968
# Epoch 7 Batch 1000 Loss 0.0999
# Epoch 7 Batch 1100 Loss 0.1300
# Epoch 7 Batch 1200 Loss 0.1272
# Epoch 7 Loss 0.1092
# Time taken for 1 epoch 1108.2236003875732 sec
#
# Epoch 8 Batch 0 Loss 0.0905
# Epoch 8 Batch 100 Loss 0.0864
# Epoch 8 Batch 200 Loss 0.0535
# Epoch 8 Batch 300 Loss 0.0823
# Epoch 8 Batch 400 Loss 0.1098
# Epoch 8 Batch 500 Loss 0.0717
# Epoch 8 Batch 600 Loss 0.1109
# Epoch 8 Batch 700 Loss 0.0634
# Epoch 8 Batch 800 Loss 0.1106
# Epoch 8 Batch 900 Loss 0.0909
# Epoch 8 Batch 1000 Loss 0.1115
# Epoch 8 Batch 1100 Loss 0.1398
# Epoch 8 Batch 1200 Loss 0.0900
# Epoch 8 Loss 0.0957
# Time taken for 1 epoch 1144.6689343452454 sec
#
# Epoch 9 Batch 0 Loss 0.0720
# Epoch 9 Batch 100 Loss 0.1107
# Epoch 9 Batch 200 Loss 0.0536
# Epoch 9 Batch 300 Loss 0.0908
# Epoch 9 Batch 400 Loss 0.0842
# Epoch 9 Batch 500 Loss 0.0948
# Epoch 9 Batch 600 Loss 0.0915
# Epoch 9 Batch 700 Loss 0.1205
# Epoch 9 Batch 800 Loss 0.0854
# Epoch 9 Batch 900 Loss 0.0765
# Epoch 9 Batch 1000 Loss 0.1229
# Epoch 9 Batch 1100 Loss 0.0794
# Epoch 9 Batch 1200 Loss 0.0954
# Epoch 9 Loss 0.0881
# Time taken for 1 epoch 1225.573496580124 sec
#
# Epoch 10 Batch 0 Loss 0.0629
# Epoch 10 Batch 100 Loss 0.0604
# Epoch 10 Batch 200 Loss 0.0820
# Epoch 10 Batch 300 Loss 0.0875
# Epoch 10 Batch 400 Loss 0.0760
# Epoch 10 Batch 500 Loss 0.0886
# Epoch 10 Batch 600 Loss 0.0992
# Epoch 10 Batch 700 Loss 0.0795
# Epoch 10 Batch 800 Loss 0.0858
# Epoch 10 Batch 900 Loss 0.1157
# Epoch 10 Batch 1000 Loss 0.0847
# Epoch 10 Batch 1100 Loss 0.0997
# Epoch 10 Batch 1200 Loss 0.0562
# Epoch 10 Loss 0.0824
# Time taken for 1 epoch 1219.4501013755798 sec
#
# Epoch 11 Batch 0 Loss 0.0587
# Epoch 11 Batch 100 Loss 0.0623
# Epoch 11 Batch 200 Loss 0.1026
# Epoch 11 Batch 300 Loss 0.0730
# Epoch 11 Batch 400 Loss 0.0836
# Epoch 11 Batch 500 Loss 0.1059
# Epoch 11 Batch 600 Loss 0.0609
# Epoch 11 Batch 700 Loss 0.0706
# Epoch 11 Batch 800 Loss 0.0781
# Epoch 11 Batch 900 Loss 0.1280
# Epoch 11 Batch 1000 Loss 0.0721
# Epoch 11 Batch 1100 Loss 0.0643
# Epoch 11 Batch 1200 Loss 0.0770
# Epoch 11 Loss 0.0786
# Time taken for 1 epoch 1186.6043829917908 sec
#
# Epoch 12 Batch 0 Loss 0.0510
# Epoch 12 Batch 100 Loss 0.0568
# Epoch 12 Batch 200 Loss 0.0514
# Epoch 12 Batch 300 Loss 0.0894
# Epoch 12 Batch 400 Loss 0.0569
# Epoch 12 Batch 500 Loss 0.0590
# Epoch 12 Batch 600 Loss 0.0788
# Epoch 12 Batch 700 Loss 0.1000
# Epoch 12 Batch 800 Loss 0.0748
# Epoch 12 Batch 900 Loss 0.0635
# Epoch 12 Batch 1000 Loss 0.0755
# Epoch 12 Batch 1100 Loss 0.0642
# Epoch 12 Batch 1200 Loss 0.0783
# Epoch 12 Loss 0.0751
# Time taken for 1 epoch 1215.018714427948 sec
#
# Epoch 13 Batch 0 Loss 0.0480
# Epoch 13 Batch 100 Loss 0.0663
# Epoch 13 Batch 200 Loss 0.0353
# Epoch 13 Batch 300 Loss 0.0558
# Epoch 13 Batch 400 Loss 0.0408
# Epoch 13 Batch 500 Loss 0.0776
# Epoch 13 Batch 600 Loss 0.0627
# Epoch 13 Batch 700 Loss 0.0769
# Epoch 13 Batch 800 Loss 0.0688
# Epoch 13 Batch 900 Loss 0.0705
# Epoch 13 Batch 1000 Loss 0.0591
# Epoch 13 Batch 1100 Loss 0.1036
# Epoch 13 Batch 1200 Loss 0.0816
# Epoch 13 Loss 0.0740
# Time taken for 1 epoch 1230.2513177394867 sec
#
# Epoch 14 Batch 0 Loss 0.0596
# Epoch 14 Batch 100 Loss 0.0516
# Epoch 14 Batch 200 Loss 0.0603
# Epoch 14 Batch 300 Loss 0.0527
# Epoch 14 Batch 400 Loss 0.0837
# Epoch 14 Batch 500 Loss 0.0540
# Epoch 14 Batch 600 Loss 0.0668
# Epoch 14 Batch 700 Loss 0.0664
# Epoch 14 Batch 800 Loss 0.0937
# Epoch 14 Batch 900 Loss 0.1033
# Epoch 14 Batch 1000 Loss 0.0789
# Epoch 14 Batch 1100 Loss 0.1195
# Epoch 14 Batch 1200 Loss 0.0820
# Epoch 14 Loss 0.0712
# Time taken for 1 epoch 1195.3818020820618 sec
#
# Epoch 15 Batch 0 Loss 0.0581
# Epoch 15 Batch 100 Loss 0.0376
# Epoch 15 Batch 200 Loss 0.0600
# Epoch 15 Batch 300 Loss 0.0850
# Epoch 15 Batch 400 Loss 0.0694
# Epoch 15 Batch 500 Loss 0.0793
# Epoch 15 Batch 600 Loss 0.0575
# Epoch 15 Batch 700 Loss 0.0515
# Epoch 15 Batch 800 Loss 0.1008
# Epoch 15 Batch 900 Loss 0.1130
# Epoch 15 Batch 1000 Loss 0.0516
# Epoch 15 Batch 1100 Loss 0.1017
# Epoch 15 Batch 1200 Loss 0.0915
# Epoch 15 Loss 0.0692
# Time taken for 1 epoch 1202.0643517971039 sec
#
# Epoch 16 Batch 0 Loss 0.0901
# Epoch 16 Batch 100 Loss 0.0559
# Epoch 16 Batch 200 Loss 0.0434
# Epoch 16 Batch 300 Loss 0.0656
# Epoch 16 Batch 400 Loss 0.0747
# Epoch 16 Batch 500 Loss 0.0591
# Epoch 16 Batch 600 Loss 0.0554
# Epoch 16 Batch 700 Loss 0.0587
# Epoch 16 Batch 800 Loss 0.0873
# Epoch 16 Batch 900 Loss 0.1223
# Epoch 16 Batch 1000 Loss 0.0889
# Epoch 16 Batch 1100 Loss 0.0599
# Epoch 16 Batch 1200 Loss 0.0772
# Epoch 16 Loss 0.0678
# Time taken for 1 epoch 1152.072560787201 sec
#
# Epoch 17 Batch 0 Loss 0.0437
# Epoch 17 Batch 100 Loss 0.0647
# Epoch 17 Batch 200 Loss 0.0715
# Epoch 17 Batch 300 Loss 0.0500
# Epoch 17 Batch 400 Loss 0.0307
# Epoch 17 Batch 500 Loss 0.0587
# Epoch 17 Batch 600 Loss 0.0381
# Epoch 17 Batch 700 Loss 0.0760
# Epoch 17 Batch 800 Loss 0.0656
# Epoch 17 Batch 900 Loss 0.0806
# Epoch 17 Batch 1000 Loss 0.1017
# Epoch 17 Batch 1100 Loss 0.0728
# Epoch 17 Batch 1200 Loss 0.0825
# Epoch 17 Loss 0.0662
# Time taken for 1 epoch 1165.89102768898 sec
#
# Epoch 18 Batch 0 Loss 0.0308
# Epoch 18 Batch 100 Loss 0.0656
# Epoch 18 Batch 200 Loss 0.0422
# Epoch 18 Batch 300 Loss 0.0773
# Epoch 18 Batch 400 Loss 0.0484
# Epoch 18 Batch 500 Loss 0.1162
# Epoch 18 Batch 600 Loss 0.0675
# Epoch 18 Batch 700 Loss 0.0241
# Epoch 18 Batch 800 Loss 0.0452
# Epoch 18 Batch 900 Loss 0.0429
# Epoch 18 Batch 1000 Loss 0.0663
# Epoch 18 Batch 1100 Loss 0.0705
# Epoch 18 Batch 1200 Loss 0.0968
# Epoch 18 Loss 0.0643
# Time taken for 1 epoch 1228.3260338306427 sec
#
# Epoch 19 Batch 0 Loss 0.0275
# Epoch 19 Batch 100 Loss 0.0412
# Epoch 19 Batch 200 Loss 0.0482
# Epoch 19 Batch 300 Loss 0.0554
# Epoch 19 Batch 400 Loss 0.0550
# Epoch 19 Batch 500 Loss 0.0438
# Epoch 19 Batch 600 Loss 0.0730
# Epoch 19 Batch 700 Loss 0.0814
# Epoch 19 Batch 800 Loss 0.0759
# Epoch 19 Batch 900 Loss 0.0383
# Epoch 19 Batch 1000 Loss 0.0620
# Epoch 19 Batch 1100 Loss 0.0585
# Epoch 19 Batch 1200 Loss 0.0712
# Epoch 19 Loss 0.0632
# Time taken for 1 epoch 1213.810257434845 sec
#
# Epoch 20 Batch 0 Loss 0.0356
# Epoch 20 Batch 100 Loss 0.0401
# Epoch 20 Batch 200 Loss 0.0718
# Epoch 20 Batch 300 Loss 0.0294
# Epoch 20 Batch 400 Loss 0.0666
# Epoch 20 Batch 500 Loss 0.0324
# Epoch 20 Batch 600 Loss 0.0445
# Epoch 20 Batch 700 Loss 0.0622
# Epoch 20 Batch 800 Loss 0.0543
# Epoch 20 Batch 900 Loss 0.0888
# Epoch 20 Batch 1000 Loss 0.1135
# Epoch 20 Batch 1100 Loss 0.0853
# Epoch 20 Batch 1200 Loss 0.0863
# Epoch 20 Loss 0.0628
# Time taken for 1 epoch 1175.6972031593323 sec
#
# Epoch 21 Batch 0 Loss 0.0411
# Epoch 21 Batch 100 Loss 0.0134
# Epoch 21 Batch 200 Loss 0.0233
# Epoch 21 Batch 300 Loss 0.0540
# Epoch 21 Batch 400 Loss 0.0375
# Epoch 21 Batch 500 Loss 0.0684
# Epoch 21 Batch 600 Loss 0.0571
# Epoch 21 Batch 700 Loss 0.0742
# Epoch 21 Batch 800 Loss 0.0472
# Epoch 21 Batch 900 Loss 0.0939
# Epoch 21 Batch 1000 Loss 0.0713
# Epoch 21 Batch 1100 Loss 0.0550
# Epoch 21 Batch 1200 Loss 0.1084
# Epoch 21 Loss 0.0613
# Time taken for 1 epoch 1182.667897939682 sec
#
# Epoch 22 Batch 0 Loss 0.0472
# Epoch 22 Batch 100 Loss 0.0357
# Epoch 22 Batch 200 Loss 0.0978
# Epoch 22 Batch 300 Loss 0.0447
# Epoch 22 Batch 400 Loss 0.0688
# Epoch 22 Batch 500 Loss 0.0381
# Epoch 22 Batch 600 Loss 0.0429
# Epoch 22 Batch 700 Loss 0.0538
# Epoch 22 Batch 800 Loss 0.0827
# Epoch 22 Batch 900 Loss 0.1122
# Epoch 22 Batch 1000 Loss 0.0698
# Epoch 22 Batch 1100 Loss 0.0658
# Epoch 22 Batch 1200 Loss 0.0793
# Epoch 22 Loss 0.0607
# Time taken for 1 epoch 1216.9926643371582 sec
#
# Epoch 23 Batch 0 Loss 0.0319
# Epoch 23 Batch 100 Loss 0.0566
# Epoch 23 Batch 200 Loss 0.0335
# Epoch 23 Batch 300 Loss 0.0704
# Epoch 23 Batch 400 Loss 0.0528
# Epoch 23 Batch 500 Loss 0.0600
# Epoch 23 Batch 600 Loss 0.0371
# Epoch 23 Batch 700 Loss 0.0450
# Epoch 23 Batch 800 Loss 0.0694
# Epoch 23 Batch 900 Loss 0.0890
# Epoch 23 Batch 1000 Loss 0.0816
# Epoch 23 Batch 1100 Loss 0.0793
# Epoch 23 Batch 1200 Loss 0.0729
# Epoch 23 Loss 0.0595
# Time taken for 1 epoch 1233.8143117427826 sec
#
# Epoch 24 Batch 0 Loss 0.0365
# Epoch 24 Batch 100 Loss 0.0326
# Epoch 24 Batch 200 Loss 0.0471
# Epoch 24 Batch 300 Loss 0.0275
# Epoch 24 Batch 400 Loss 0.0517
# Epoch 24 Batch 500 Loss 0.0586
# Epoch 24 Batch 600 Loss 0.0552
# Epoch 24 Batch 700 Loss 0.0649
# Epoch 24 Batch 800 Loss 0.0680
# Epoch 24 Batch 900 Loss 0.0532
# Epoch 24 Batch 1000 Loss 0.0427
# Epoch 24 Batch 1100 Loss 0.1036
# Epoch 24 Batch 1200 Loss 0.0482
# Epoch 24 Loss 0.0587
# Time taken for 1 epoch 1258.6293678283691 sec
#
# Epoch 25 Batch 0 Loss 0.0402
# Epoch 25 Batch 100 Loss 0.0342
# Epoch 25 Batch 200 Loss 0.0411
# Epoch 25 Batch 300 Loss 0.0593
# Epoch 25 Batch 400 Loss 0.0611
# Epoch 25 Batch 500 Loss 0.0551
# Epoch 25 Batch 600 Loss 0.0689
# Epoch 25 Batch 700 Loss 0.0533
# Epoch 25 Batch 800 Loss 0.0703
# Epoch 25 Batch 900 Loss 0.0890
# Epoch 25 Batch 1000 Loss 0.0842
# Epoch 25 Batch 1100 Loss 0.0607
# Epoch 25 Batch 1200 Loss 0.0663
# Epoch 25 Loss 0.0577
# Time taken for 1 epoch 1296.2467305660248 sec
#
# Epoch 26 Batch 0 Loss 0.0349
# Epoch 26 Batch 100 Loss 0.0549
# Epoch 26 Batch 200 Loss 0.0467
# Epoch 26 Batch 300 Loss 0.0890
# Epoch 26 Batch 400 Loss 0.0809
# Epoch 26 Batch 500 Loss 0.0884
# Epoch 26 Batch 600 Loss 0.0692
# Epoch 26 Batch 700 Loss 0.0636
# Epoch 26 Batch 800 Loss 0.0508
# Epoch 26 Batch 900 Loss 0.0473
# Epoch 26 Batch 1000 Loss 0.0487
# Epoch 26 Batch 1100 Loss 0.0588
# Epoch 26 Batch 1200 Loss 0.0893
# Epoch 26 Loss 0.0573
# Time taken for 1 epoch 1419.809428691864 sec
#
# Epoch 27 Batch 0 Loss 0.0320
# Epoch 27 Batch 100 Loss 0.0294
# Epoch 27 Batch 200 Loss 0.0227
# Epoch 27 Batch 300 Loss 0.0324
# Epoch 27 Batch 400 Loss 0.0442
# Epoch 27 Batch 500 Loss 0.0611
# Epoch 27 Batch 600 Loss 0.0469
# Epoch 27 Batch 700 Loss 0.0852
# Epoch 27 Batch 800 Loss 0.0479
# Epoch 27 Batch 900 Loss 0.0947
# Epoch 27 Batch 1000 Loss 0.0578
# Epoch 27 Batch 1100 Loss 0.0699
# Epoch 27 Batch 1200 Loss 0.0681
# Epoch 27 Loss 0.0555
# Time taken for 1 epoch 1114.9555325508118 sec
#
# Epoch 28 Batch 0 Loss 0.0387
# Epoch 28 Batch 100 Loss 0.0257
# Epoch 28 Batch 200 Loss 0.0353
# Epoch 28 Batch 300 Loss 0.0282
# Epoch 28 Batch 400 Loss 0.0469
# Epoch 28 Batch 500 Loss 0.0432
# Epoch 28 Batch 600 Loss 0.0684
# Epoch 28 Batch 700 Loss 0.0853
# Epoch 28 Batch 800 Loss 0.0499
# Epoch 28 Batch 900 Loss 0.0615
# Epoch 28 Batch 1000 Loss 0.0663
# Epoch 28 Batch 1100 Loss 0.0683
# Epoch 28 Batch 1200 Loss 0.0636
# Epoch 28 Loss 0.0551
# Time taken for 1 epoch 1054.3932654857635 sec
#
# Epoch 29 Batch 0 Loss 0.0732
# Epoch 29 Batch 100 Loss 0.0265
# Epoch 29 Batch 200 Loss 0.0615
# Epoch 29 Batch 300 Loss 0.1120
# Epoch 29 Batch 400 Loss 0.0657
# Epoch 29 Batch 500 Loss 0.0757
# Epoch 29 Batch 600 Loss 0.0476
# Epoch 29 Batch 700 Loss 0.0582
# Epoch 29 Batch 800 Loss 0.0845
# Epoch 29 Batch 900 Loss 0.0554
# Epoch 29 Batch 1000 Loss 0.0674
# Epoch 29 Batch 1100 Loss 0.0387
# Epoch 29 Batch 1200 Loss 0.0586
# Epoch 29 Loss 0.0546
# Time taken for 1 epoch 1056.1964693069458 sec
#
# Epoch 30 Batch 0 Loss 0.0532
# Epoch 30 Batch 100 Loss 0.0337
# Epoch 30 Batch 200 Loss 0.0342
# Epoch 30 Batch 300 Loss 0.0244
# Epoch 30 Batch 400 Loss 0.0628
# Epoch 30 Batch 500 Loss 0.0417
# Epoch 30 Batch 600 Loss 0.0344
# Epoch 30 Batch 700 Loss 0.0267
# Epoch 30 Batch 800 Loss 0.0669
# Epoch 30 Batch 900 Loss 0.0645
# Epoch 30 Batch 1000 Loss 0.1034
# Epoch 30 Batch 1100 Loss 0.0824
# Epoch 30 Batch 1200 Loss 0.0698
# Epoch 30 Loss 0.0535
# Time taken for 1 epoch 1138.6561954021454 sec
#
# Epoch 31 Batch 0 Loss 0.0293
# Epoch 31 Batch 100 Loss 0.0409
# Epoch 31 Batch 200 Loss 0.0318
# Epoch 31 Batch 300 Loss 0.0677
# Epoch 31 Batch 400 Loss 0.0691
# Epoch 31 Batch 500 Loss 0.0659
# Epoch 31 Batch 600 Loss 0.0438
# Epoch 31 Batch 700 Loss 0.0674
# Epoch 31 Batch 800 Loss 0.0344
# Epoch 31 Batch 900 Loss 0.0582
# Epoch 31 Batch 1000 Loss 0.0338
# Epoch 31 Batch 1100 Loss 0.0618
# Epoch 31 Batch 1200 Loss 0.1008
# Epoch 31 Loss 0.0529
# Time taken for 1 epoch 1141.665964603424 sec
#
# Epoch 32 Batch 0 Loss 0.0710
# Epoch 32 Batch 100 Loss 0.0171
# Epoch 32 Batch 200 Loss 0.0424
# Epoch 32 Batch 300 Loss 0.0378
# Epoch 32 Batch 400 Loss 0.0544
# Epoch 32 Batch 500 Loss 0.0634
# Epoch 32 Batch 600 Loss 0.0456
# Epoch 32 Batch 700 Loss 0.0410
# Epoch 32 Batch 800 Loss 0.0370
# Epoch 32 Batch 900 Loss 0.0608
# Epoch 32 Batch 1000 Loss 0.0431
# Epoch 32 Batch 1100 Loss 0.1102
# Epoch 32 Batch 1200 Loss 0.0483
# Epoch 32 Loss 0.0525
# Time taken for 1 epoch 1053.3559210300446 sec
#
# Epoch 33 Batch 0 Loss 0.0419
# Epoch 33 Batch 100 Loss 0.0280
# Epoch 33 Batch 200 Loss 0.0295
# Epoch 33 Batch 300 Loss 0.0308
# Epoch 33 Batch 400 Loss 0.0527
# Epoch 33 Batch 500 Loss 0.0455
# Epoch 33 Batch 600 Loss 0.0373
# Epoch 33 Batch 700 Loss 0.0534
# Epoch 33 Batch 800 Loss 0.0511
# Epoch 33 Batch 900 Loss 0.0569
# Epoch 33 Batch 1000 Loss 0.0716
# Epoch 33 Batch 1100 Loss 0.0681
# Epoch 33 Batch 1200 Loss 0.0799
# Epoch 33 Loss 0.0517
# Time taken for 1 epoch 1073.4080810546875 sec
#
# Epoch 34 Batch 0 Loss 0.0412
# Epoch 34 Batch 100 Loss 0.0649
# Epoch 34 Batch 200 Loss 0.0366
# Epoch 34 Batch 300 Loss 0.0164
# Epoch 34 Batch 400 Loss 0.0594
# Epoch 34 Batch 500 Loss 0.0464
# Epoch 34 Batch 600 Loss 0.0476
# Epoch 34 Batch 700 Loss 0.0396
# Epoch 34 Batch 800 Loss 0.0320
# Epoch 34 Batch 900 Loss 0.0399
# Epoch 34 Batch 1000 Loss 0.0523
# Epoch 34 Batch 1100 Loss 0.0759
# Epoch 34 Batch 1200 Loss 0.0578
# Epoch 34 Loss 0.0512
# Time taken for 1 epoch 1095.839280128479 sec
#
# Epoch 35 Batch 0 Loss 0.0110
# Epoch 35 Batch 100 Loss 0.0590
# Epoch 35 Batch 200 Loss 0.0252
# Epoch 35 Batch 300 Loss 0.0552
# Epoch 35 Batch 400 Loss 0.0551
# Epoch 35 Batch 500 Loss 0.0242
# Epoch 35 Batch 600 Loss 0.0498
# Epoch 35 Batch 700 Loss 0.0662
# Epoch 35 Batch 800 Loss 0.0374
# Epoch 35 Batch 900 Loss 0.0819
# Epoch 35 Batch 1000 Loss 0.0447
# Epoch 35 Batch 1100 Loss 0.0578
# Epoch 35 Batch 1200 Loss 0.0658
# Epoch 35 Loss 0.0505
# Time taken for 1 epoch 1173.1663656234741 sec
#
# Epoch 36 Batch 0 Loss 0.0246
# Epoch 36 Batch 100 Loss 0.0663
# Epoch 36 Batch 200 Loss 0.0319
# Epoch 36 Batch 300 Loss 0.0354
# Epoch 36 Batch 400 Loss 0.0374
# Epoch 36 Batch 500 Loss 0.0569
# Epoch 36 Batch 600 Loss 0.0541
# Epoch 36 Batch 700 Loss 0.0460
# Epoch 36 Batch 800 Loss 0.0508
# Epoch 36 Batch 900 Loss 0.0532
# Epoch 36 Batch 1000 Loss 0.0462
# Epoch 36 Batch 1100 Loss 0.0475
# Epoch 36 Batch 1200 Loss 0.0618
# Epoch 36 Loss 0.0502
# Time taken for 1 epoch 1443.7949714660645 sec
#
# Epoch 37 Batch 0 Loss 0.0333
# Epoch 37 Batch 100 Loss 0.0474
# Epoch 37 Batch 200 Loss 0.0416
# Epoch 37 Batch 300 Loss 0.0435
# Epoch 37 Batch 400 Loss 0.0444
# Epoch 37 Batch 500 Loss 0.0487
# Epoch 37 Batch 600 Loss 0.0263
# Epoch 37 Batch 700 Loss 0.0582
# Epoch 37 Batch 800 Loss 0.0612
# Epoch 37 Batch 900 Loss 0.0775
# Epoch 37 Batch 1000 Loss 0.0559
# Epoch 37 Batch 1100 Loss 0.0434
# Epoch 37 Batch 1200 Loss 0.0532
# Epoch 37 Loss 0.0494
# Time taken for 1 epoch 26675.997575759888 sec
#
# Epoch 38 Batch 0 Loss 0.0274
# Epoch 38 Batch 100 Loss 0.0454
# Epoch 38 Batch 200 Loss 0.0493
# Epoch 38 Batch 300 Loss 0.0357
# Epoch 38 Batch 400 Loss 0.0638
# Epoch 38 Batch 500 Loss 0.0541
# Epoch 38 Batch 600 Loss 0.0932
# Epoch 38 Batch 700 Loss 0.0724
# Epoch 38 Batch 800 Loss 0.0686
# Epoch 38 Batch 900 Loss 0.0508
# Epoch 38 Batch 1000 Loss 0.0782
# Epoch 38 Batch 1100 Loss 0.0748
# Epoch 38 Batch 1200 Loss 0.0645
# Epoch 38 Loss 0.0494
# Time taken for 1 epoch 989.0985524654388 sec
#
# Epoch 39 Batch 0 Loss 0.0495
# Epoch 39 Batch 100 Loss 0.0539
# Epoch 39 Batch 200 Loss 0.0559
# Epoch 39 Batch 300 Loss 0.0352
# Epoch 39 Batch 400 Loss 0.0278
# Epoch 39 Batch 500 Loss 0.0506
# Epoch 39 Batch 600 Loss 0.0244
# Epoch 39 Batch 700 Loss 0.0461
# Epoch 39 Batch 800 Loss 0.0301
# Epoch 39 Batch 900 Loss 0.0348
# Epoch 39 Batch 1000 Loss 0.0631
# Epoch 39 Batch 1100 Loss 0.0744
# Epoch 39 Batch 1200 Loss 0.0497
# Epoch 39 Loss 0.0486
# Time taken for 1 epoch 1010.5810084342957 sec
#
# Epoch 40 Batch 0 Loss 0.0101
# Epoch 40 Batch 100 Loss 0.0361
# Epoch 40 Batch 200 Loss 0.0277
# Epoch 40 Batch 300 Loss 0.0217
# Epoch 40 Batch 400 Loss 0.0418
# Epoch 40 Batch 500 Loss 0.0441
# Epoch 40 Batch 600 Loss 0.0606
# Epoch 40 Batch 700 Loss 0.0449
# Epoch 40 Batch 800 Loss 0.0728
# Epoch 40 Batch 900 Loss 0.0674
# Epoch 40 Batch 1000 Loss 0.0681
# Epoch 40 Batch 1100 Loss 0.0392
# Epoch 40 Batch 1200 Loss 0.0634
# Epoch 40 Loss 0.0480
# Time taken for 1 epoch 1007.6215906143188 sec
#
# Epoch 41 Batch 0 Loss 0.0513
# Epoch 41 Batch 100 Loss 0.0365
# Epoch 41 Batch 200 Loss 0.0243
# Epoch 41 Batch 300 Loss 0.0407
# Epoch 41 Batch 400 Loss 0.0667
# Epoch 41 Batch 500 Loss 0.0437
# Epoch 41 Batch 600 Loss 0.0317
# Epoch 41 Batch 700 Loss 0.0598
# Epoch 41 Batch 800 Loss 0.0360
# Epoch 41 Batch 900 Loss 0.0454
# Epoch 41 Batch 1000 Loss 0.0639
# Epoch 41 Batch 1100 Loss 0.0444
# Epoch 41 Batch 1200 Loss 0.0364
# Epoch 41 Loss 0.0473
# Time taken for 1 epoch 3497.805950164795 sec
#
# Epoch 42 Batch 0 Loss 0.0525
# Epoch 42 Batch 100 Loss 0.0220
# Epoch 42 Batch 200 Loss 0.0301
# Epoch 42 Batch 300 Loss 0.0735
# Epoch 42 Batch 400 Loss 0.0484
# Epoch 42 Batch 500 Loss 0.0408
# Epoch 42 Batch 600 Loss 0.0592
# Epoch 42 Batch 700 Loss 0.0729
# Epoch 42 Batch 800 Loss 0.0441
# Epoch 42 Batch 900 Loss 0.0267
# Epoch 42 Batch 1000 Loss 0.0408
# Epoch 42 Batch 1100 Loss 0.0430
# Epoch 42 Batch 1200 Loss 0.0594
# Epoch 42 Loss 0.0479
# Time taken for 1 epoch 1079.512139081955 sec
#
# Epoch 43 Batch 0 Loss 0.0205
# Epoch 43 Batch 100 Loss 0.0562
# Epoch 43 Batch 200 Loss 0.0365
# Epoch 43 Batch 300 Loss 0.0475
# Epoch 43 Batch 400 Loss 0.0463
# Epoch 43 Batch 500 Loss 0.0292
# Epoch 43 Batch 600 Loss 0.0569
# Epoch 43 Batch 700 Loss 0.0482
# Epoch 43 Batch 800 Loss 0.0296
# Epoch 43 Batch 900 Loss 0.0355
# Epoch 43 Batch 1000 Loss 0.0284
# Epoch 43 Batch 1100 Loss 0.0660
# Epoch 43 Batch 1200 Loss 0.1239
# Epoch 43 Loss 0.0467
# Time taken for 1 epoch 1122.4268794059753 sec
#
# Epoch 44 Batch 0 Loss 0.0372
# Epoch 44 Batch 100 Loss 0.0341
# Epoch 44 Batch 200 Loss 0.0297
# Epoch 44 Batch 300 Loss 0.0529
# Epoch 44 Batch 400 Loss 0.0550
# Epoch 44 Batch 500 Loss 0.0701
# Epoch 44 Batch 600 Loss 0.0323
# Epoch 44 Batch 700 Loss 0.0432
# Epoch 44 Batch 800 Loss 0.0504
# Epoch 44 Batch 900 Loss 0.0642
# Epoch 44 Batch 1000 Loss 0.0651
# Epoch 44 Batch 1100 Loss 0.0863
# Epoch 44 Batch 1200 Loss 0.0328
# Epoch 44 Loss 0.0467
# Time taken for 1 epoch 1108.4520163536072 sec
#
# Epoch 45 Batch 0 Loss 0.0293
# Epoch 45 Batch 100 Loss 0.0552
# Epoch 45 Batch 200 Loss 0.0319
# Epoch 45 Batch 300 Loss 0.0221
# Epoch 45 Batch 400 Loss 0.0398
# Epoch 45 Batch 500 Loss 0.0258
# Epoch 45 Batch 600 Loss 0.0250
# Epoch 45 Batch 700 Loss 0.0436
# Epoch 45 Batch 800 Loss 0.0578
# Epoch 45 Batch 900 Loss 0.0586
# Epoch 45 Batch 1000 Loss 0.0510
# Epoch 45 Batch 1100 Loss 0.0872
# Epoch 45 Batch 1200 Loss 0.0497
# Epoch 45 Loss 0.0461
# Time taken for 1 epoch 1177.3330368995667 sec
#
# Epoch 46 Batch 0 Loss 0.0391
# Epoch 46 Batch 100 Loss 0.0275
# Epoch 46 Batch 200 Loss 0.0360
# Epoch 46 Batch 300 Loss 0.0297
# Epoch 46 Batch 400 Loss 0.0339
# Epoch 46 Batch 500 Loss 0.0404
# Epoch 46 Batch 600 Loss 0.0312
# Epoch 46 Batch 700 Loss 0.0318
# Epoch 46 Batch 800 Loss 0.0530
# Epoch 46 Batch 900 Loss 0.0452
# Epoch 46 Batch 1000 Loss 0.0285
# Epoch 46 Batch 1100 Loss 0.0336
# Epoch 46 Batch 1200 Loss 0.0487
# Epoch 46 Loss 0.0452
# Time taken for 1 epoch 1234.437434911728 sec
#
# Epoch 47 Batch 0 Loss 0.0413
# Epoch 47 Batch 100 Loss 0.0529
# Epoch 47 Batch 200 Loss 0.0481
# Epoch 47 Batch 300 Loss 0.0392
# Epoch 47 Batch 400 Loss 0.0482
# Epoch 47 Batch 500 Loss 0.0428
# Epoch 47 Batch 600 Loss 0.0365
# Epoch 47 Batch 700 Loss 0.0296
# Epoch 47 Batch 800 Loss 0.0558
# Epoch 47 Batch 900 Loss 0.0375
# Epoch 47 Batch 1000 Loss 0.0497
# Epoch 47 Batch 1100 Loss 0.0343
# Epoch 47 Batch 1200 Loss 0.0841
# Epoch 47 Loss 0.0456
# Time taken for 1 epoch 1202.4545497894287 sec
#
# Epoch 48 Batch 0 Loss 0.0328
# Epoch 48 Batch 100 Loss 0.0780
# Epoch 48 Batch 200 Loss 0.0390
# Epoch 48 Batch 300 Loss 0.0257
# Epoch 48 Batch 400 Loss 0.0419
# Epoch 48 Batch 500 Loss 0.0329
# Epoch 48 Batch 600 Loss 0.0867
# Epoch 48 Batch 700 Loss 0.0368
# Epoch 48 Batch 800 Loss 0.0349
# Epoch 48 Batch 900 Loss 0.0561
# Epoch 48 Batch 1000 Loss 0.0623
# Epoch 48 Batch 1100 Loss 0.0574
# Epoch 48 Batch 1200 Loss 0.0699
# Epoch 48 Loss 0.0450
# Time taken for 1 epoch 1114.0707454681396 sec
#
# Epoch 49 Batch 0 Loss 0.0228
# Epoch 49 Batch 100 Loss 0.0432
# Epoch 49 Batch 200 Loss 0.0395
# Epoch 49 Batch 300 Loss 0.0333
# Epoch 49 Batch 400 Loss 0.0573
# Epoch 49 Batch 500 Loss 0.0351
# Epoch 49 Batch 600 Loss 0.0523
# Epoch 49 Batch 700 Loss 0.0509
# Epoch 49 Batch 800 Loss 0.0561
# Epoch 49 Batch 900 Loss 0.0772
# Epoch 49 Batch 1000 Loss 0.0285
# Epoch 49 Batch 1100 Loss 0.0786
# Epoch 49 Batch 1200 Loss 0.0420
# Epoch 49 Loss 0.0451
# Time taken for 1 epoch 1080.813853263855 sec
#
# Epoch 50 Batch 0 Loss 0.0359
# Epoch 50 Batch 100 Loss 0.0331
# Epoch 50 Batch 200 Loss 0.0227
# Epoch 50 Batch 300 Loss 0.0409
# Epoch 50 Batch 400 Loss 0.0388
# Epoch 50 Batch 500 Loss 0.0407
# Epoch 50 Batch 600 Loss 0.0735
# Epoch 50 Batch 700 Loss 0.0641
# Epoch 50 Batch 800 Loss 0.0650
# Epoch 50 Batch 900 Loss 0.0504
# Epoch 50 Batch 1000 Loss 0.0401
# Epoch 50 Batch 1100 Loss 0.0299
# Epoch 50 Batch 1200 Loss 0.0771
# Epoch 50 Loss 0.0441
# Time taken for 1 epoch 1144.4616186618805 sec

# %%
def evaluate(sentence):
  #attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print(f'Input: {sentence}')
  print(f'Predicted translation: {result}')

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Все было хорошо')
# Out:
# Input: <start> все было хорошо <end>
# Predicted translation: was all right ? <end>

# %%
translate('Что вы делали вчера?')
# Out:
# Input: <start> что вы делали вчера ? <end>
# Predicted translation: what were you seen ? <end>
